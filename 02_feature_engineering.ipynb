# %% [markdown]
# <a href="https://colab.research.google.com/github/hamdikhasawneh/AI-sepsis/blob/main/02_feature_engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
from pathlib import Path

print("Current working directory:", Path.cwd())
print("Files here:", os.listdir())
print("Parent exists:", Path("..").exists())
if Path("..").exists():
    print("Parent files:", os.listdir(".."))
# Out:
# Current working directory: /content
# Files here: ['.config', 'AI-sepsis', 'drive', 'sample_data']
# Parent exists: True
# Parent files: ['proc', 'sys', 'mnt', 'tmp', 'etc', 'run', 'bin', 'boot', 'usr', 'sbin', 'srv', 'lib32', 'media', 'home', 'lib64', 'lib', 'root', 'var', 'libx32', 'opt', 'dev', 'kaggle', 'content', '.dockerenv', 'tools', 'datalab', 'python-apt', 'python-apt.tar.xz']

# %%
# !git clone https://github.com/hamdikhasawneh/AI-sepsis.git
# Out:
# fatal: destination path 'AI-sepsis' already exists and is not an empty directory.

# %%
# !ls /content
# Out:
# AI-sepsis  drive  sample_data

# %%
import sys
from pathlib import Path

sys.path.insert(0, "/content/AI-sepsis")

# %%
from src.preprocessing import run_preprocessing

# %%
results = run_preprocessing(
    data_dir="/content/drive/MyDrive/gp/Cleaned",
    output_dir="/content/drive/MyDrive/mimic_iv_processed",
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_14255/2817563656.py in <cell line: 0>()
# ----> 1 results = run_preprocessing(
#       2     data_dir="/content/drive/MyDrive/gp/Cleaned",
#       3     output_dir="/content/drive/MyDrive/mimic_iv_processed",
#       4 )
#
# /content/AI-sepsis/src/preprocessing.py in run_preprocessing(data_dir, output_dir)
#     830
#     831     # SOFA labs
# --> 832     labs = extract_sofa_labs(cohort, config)
#     833     _save_csv(labs, config.output_dir / "sofa_labs_filtered.csv")
#     834
#
# /content/AI-sepsis/src/preprocessing.py in extract_sofa_labs(cohort, config, chunk_size)
#     439
#     440     if output_file.exists():
# --> 441         return pd.read_csv(output_file)
#     442
#     443     return pd.DataFrame(columns=["subject_id", "hadm_id", "charttime", "itemid", "valuenum", "stay_id"])
#
# ...

# %%
# !ls /content/drive/MyDrive/mimic_iv_processed
# Out:
# gcs_filtered.csv		suspected_infection.csv
# icu_cohort.csv			vitals_24h.csv
# sepsis_labels_multihorizon.csv	vitals_complete.csv
# sofa_labs_filtered.csv		vitals_filtered.csv
# sofa_labs_hourly_wide.csv	vitals_hourly_wide.csv

# %%
import sys
sys.path.insert(0, "/content/AI-sepsis")

from src.preprocessing import load_saved_preprocessing_outputs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_14255/3207509463.py in <cell line: 0>()
#       2 sys.path.insert(0, "/content/AI-sepsis")
#       3
# ----> 4 from src.preprocessing import load_saved_preprocessing_outputs
#
# ImportError: cannot import name 'load_saved_preprocessing_outputs' from 'src.preprocessing' (/content/AI-sepsis/src/preprocessing.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !cd /content/AI-sepsis && git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 1.30 KiB | 166.00 KiB/s, done.
# From https://github.com/hamdikhasawneh/AI-sepsis
#    b2bd594..6421c10  main       -> origin/main
# Updating b2bd594..6421c10
# Fast-forward
#  src/preprocessing.py | 30 ++++++++++++++++++++++++++++++
#  1 file changed, 30 insertions(+)

# %%
import sys
sys.path.insert(0, "/content/AI-sepsis")

from src.preprocessing import load_saved_preprocessing_outputs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_14255/3207509463.py in <cell line: 0>()
#       2 sys.path.insert(0, "/content/AI-sepsis")
#       3
# ----> 4 from src.preprocessing import load_saved_preprocessing_outputs
#
# ImportError: cannot import name 'load_saved_preprocessing_outputs' from 'src.preprocessing' (/content/AI-sepsis/src/preprocessing.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !tail -n 40 /content/AI-sepsis/src/preprocessing.py
# Out:
#         "vitals_complete": vitals_complete,
#         "X": X,
#         "stay_ids_order": stay_ids_order,
#         "labs_wide": labs_wide,
#         "gcs_wide": gcs_wide,
#         "sofa_df": sofa_df,
#         "suspected_infection": suspected_infection,
#         "sepsis_onset": sepsis_onset,
#         "labels_ordered": labels_ordered,
#     }
#     def load_saved_preprocessing_outputs(output_dir: str):
#     output_dir = Path(output_dir)
#
#     results = {}
#
#     file_map = {
#         "cohort": "icu_cohort.csv",
#         "vitals_filtered": "vitals_filtered.csv",
#         "vitals_wide": "vitals_hourly_wide.csv",
#         "vitals_24h": "vitals_24h.csv",
#         "vitals_complete": "vitals_complete.csv",
#         "labs_filtered": "sofa_labs_filtered.csv",
#         "labs_wide": "sofa_labs_hourly_wide.csv",
#         "gcs_filtered": "gcs_filtered.csv",
#         "suspected_infection": "suspected_infection.csv",
#         "labels_ordered": "sepsis_labels_multihorizon.csv",
# ...

# %%
# !cd /content/AI-sepsis && git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 1008 bytes | 504.00 KiB/s, done.
# From https://github.com/hamdikhasawneh/AI-sepsis
#    6421c10..cae79fb  main       -> origin/main
# Updating 6421c10..cae79fb
# Fast-forward
#  src/preprocessing.py | 6 ++++--
#  1 file changed, 4 insertions(+), 2 deletions(-)

# %%
import sys
sys.path.insert(0, "/content/AI-sepsis")

from src.preprocessing import load_saved_preprocessing_outputs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_14255/3207509463.py in <cell line: 0>()
#       2 sys.path.insert(0, "/content/AI-sepsis")
#       3
# ----> 4 from src.preprocessing import load_saved_preprocessing_outputs
#
# ImportError: cannot import name 'load_saved_preprocessing_outputs' from 'src.preprocessing' (/content/AI-sepsis/src/preprocessing.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import src.preprocessing as p
print(p.__file__)
print(hasattr(p, "load_saved_preprocessing_outputs"))
# Out:
# /content/AI-sepsis/src/preprocessing.py
# False

# %%
# !tail -n 50 /content/AI-sepsis/src/preprocessing.py
# Out:
#     _save_csv(sepsis_onset, config.output_dir / "sepsis_onset.csv")
#     _save_csv(labels_ordered, config.output_dir / "sepsis_labels_multihorizon.csv")
#
#         return {
#         "cohort": cohort,
#         "vitals": vitals,
#         "vitals_wide": vitals_wide,
#         "vitals_24h": vitals_24h,
#         "vitals_complete": vitals_complete,
#         "X": X,
#         "stay_ids_order": stay_ids_order,
#         "labs_wide": labs_wide,
#         "gcs_wide": gcs_wide,
#         "sofa_df": sofa_df,
#         "suspected_infection": suspected_infection,
#         "sepsis_onset": sepsis_onset,
#         "labels_ordered": labels_ordered,
#     }
#
#
# def load_saved_preprocessing_outputs(output_dir: str):
#     output_dir = Path(output_dir)
#
#     results = {}
#
#     file_map = {
#         "cohort": "icu_cohort.csv",
#         "vitals_filtered": "vitals_filtered.csv",
#         "vitals_wide": "vitals_hourly_wide.csv",
#         "vitals_24h": "vitals_24h.csv",
# ...

# %%
import importlib
import src.preprocessing as p
importlib.reload(p)
print(hasattr(p, "load_saved_preprocessing_outputs"))
print([name for name in dir(p) if "load" in name.lower()])
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "/tmp/ipykernel_14255/2950561096.py", line 3, in <cell line: 0>
#     importlib.reload(p)
#
#   File "/usr/lib/python3.12/importlib/__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#
#   File "<frozen importlib._bootstrap>", line 866, in _exec
#
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#
#   File "<frozen importlib._bootstrap_external>", line 1133, in get_code
#
#   File "<frozen importlib._bootstrap_external>", line 1063, in source_to_code
#
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#
#   File "/content/AI-sepsis/src/preprocessing.py", line 862
#     return {
#     ^
# IndentationError: unexpected indent

# %%
# !cd /content/AI-sepsis && git pull
# Out:
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 11 (delta 7), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (11/11), 75.87 KiB | 6.90 MiB/s, done.
# From https://github.com/hamdikhasawneh/AI-sepsis
#    cae79fb..14764cc  main       -> origin/main
# Updating cae79fb..14764cc
# Fast-forward
#  sepsis-detection-source.tar.gz | Bin 0 -> 74744 bytes
#  src/preprocessing.py           |   7 +++----
#  2 files changed, 3 insertions(+), 4 deletions(-)
#  create mode 100644 sepsis-detection-source.tar.gz

# %%
import sys
sys.path.insert(0, "/content/AI-sepsis")

import importlib
import src.preprocessing as p
importlib.reload(p)

from src.preprocessing import load_saved_preprocessing_outputs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_14255/4281062364.py in <cell line: 0>()
#       6 importlib.reload(p)
#       7
# ----> 8 from src.preprocessing import load_saved_preprocessing_outputs
#
# ImportError: cannot import name 'load_saved_preprocessing_outputs' from 'src.preprocessing' (/content/AI-sepsis/src/preprocessing.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
