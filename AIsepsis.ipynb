# %% [markdown]
# <a href="https://colab.research.google.com/github/hamdikhasawneh/AI-sepsis/blob/main/AIsepsis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================
# Core
# =========================
import os
import gc
import json
import time
import math
import random
import warnings
from pathlib import Path
from datetime import datetime, timedelta

warnings.filterwarnings("ignore")

# =========================
# Data
# =========================
import numpy as np
import pandas as pd

# If you read big tables efficiently:
# import pyarrow as pa
# import pyarrow.parquet as pq

# =========================
# Visualization
# =========================
import matplotlib.pyplot as plt

# Optional but very common for EDA:
# import seaborn as sns

# =========================
# Stats / Signals (helpful for vitals trends)
# =========================
from scipy import stats
from scipy.signal import savgol_filter

# Optional (strong for interpolation / time-series transforms):
# from scipy.interpolate import interp1d

# =========================
# ML utilities (scikit-learn)
# =========================
from sklearn.model_selection import (
    train_test_split,
    StratifiedKFold,
    GroupKFold,
    TimeSeriesSplit,
    cross_val_score
)

from sklearn.preprocessing import (
    StandardScaler,
    MinMaxScaler,
    RobustScaler,
    OneHotEncoder
)

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

from sklearn.metrics import (
    roc_auc_score,
    average_precision_score,   # PR-AUC (very important for imbalance)
    precision_recall_curve,
    roc_curve,
    confusion_matrix,
    classification_report,
    precision_score,
    recall_score,
    f1_score,
    accuracy_score,
    brier_score_loss
)

# Calibration (often useful in clinical risk models)
from sklearn.calibration import CalibratedClassifierCV, calibration_curve

# Baseline models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# =========================
# Imbalance handling (sepsis is often rare)
# =========================
# pip install imbalanced-learn
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as ImbPipeline

# =========================
# Gradient boosting (usually best for tabular clinical data)
# =========================
# !pip install catboost
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# =========================
# Explainability
# =========================
# pip install shap
import shap

# Optional:
# from sklearn.inspection import permutation_importance

# =========================
# Saving / loading
# =========================
import joblib

# =========================
# Optional: Deep learning (if you use LSTM/Transformer on sequences)
# =========================
# pip install torch
# import torch
# import torch.nn as nn
# from torch.utils.data import Dataset, DataLoader
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 10.6 MB/s eta 0:00:00
# ...
